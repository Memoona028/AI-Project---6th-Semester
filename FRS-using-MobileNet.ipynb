# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNet50, MobileNetV2, VGG19
from tensorflow.keras.applications.resnet50 import preprocess_input 
from tensorflow.keras.applications.vgg19 import preprocess_input as preprocess_input_vgg
import os
from tqdm import tqdm
import pickle

# %%
img_size=224
input_shape=(img_size,img_size,3)
target_size = (img_size, img_size)

# %%
base_model =ResNet50(weights = "imagenet",
                     include_top = False,
                      input_shape = input_shape)

base_model.trainable = False

# %%
base_model=tf.keras.Sequential([
    base_model,
    GlobalMaxPooling2D()
])

# %%
base_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d_1 (Gl  (None, 2048)              0
#  obalMaxPooling2D)
#
# ...
# Total params: 23587712 (89.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
#Feature Extraction

# %%
def extract_features_batch(image_paths,base_model):
    batch_images = []
    for path in image_paths:
        img = image.load_img(path, target_size=(224, 224))  
        img_array = image.img_to_array(img)
        batch_images.append(img_array)
    batch_images =  preprocess_input_mn(np.array(batch_images))
    batch_features = base_model.predict(batch_images)
    normalized_batch_features = batch_features / norm(batch_features, axis=1, keepdims=True)
    return normalized_batch_features

img_folder = 'fashion'
batch_size = 32  
img_filenames = [os.path.join(img_folder, file) for file in os.listdir(img_folder)]
feature_list = []
for i in tqdm(range(0, len(img_filenames), batch_size)):
    batch_paths = img_filenames[i:i+batch_size]
    features = extract_features_batch(batch_paths, base_model)
    feature_list.extend(features)

pickle.dump(feature_list, open('features_list_res_fas.pkl', 'wb'))
pickle.dump(img_filenames, open('image_filenames_mn_fas.pkl', 'wb'))
# Out:
# ...
# 1/1 [==============================] - 3s 3s/step
# ...
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 1368/1368 [1:27:55<00:00,  3.86s/it]

# %%
import pickle
features_list = pickle.load(open(r'C:\Users\DELL\OneDrive\Documents\AI_SEM_PROJECT\features_list_res_fas.pkl', 'rb'))
num_features = len(features_list)

# Print the number of features
print("Number of features:", num_features)
print("Shape of a single feature vector:", len(features_list[0]))
# Out:
# Number of features: 43776
# Shape of a single feature vector: 1280

# %%
import pickle

# Load the pickle file
filename_list = pickle.load(open(r'C:\Users\DELL\OneDrive\Documents\AI_SEM_PROJECT\image_filenames_mn_fas.pkl', 'rb'))

# Print the contents of the filename list
print(filename_list)
